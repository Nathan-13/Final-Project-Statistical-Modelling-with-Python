# %% [markdown]
# # CityBikes

# %% [markdown]
# Send a request to CityBikes for the city of your choice.

# %%
# Importing the require libraries
import os
import json
import requests
import pandas as pd

# %%
# Get network data
city_bike_networks = requests.get("http://api.citybik.es/v2/networks").json()
city_bike_networks

# Get data for the city of Hamilton with network_id: sobi-hamilton
network_id = 'sobi-hamilton'
network_json = requests.get("http://api.citybik.es/v2/networks/"+network_id).json()

# Convert JSON data to a string with indentation
json_str = json.dumps(network_json, indent=2, ensure_ascii=False)

# Limit the output to a certain number of characters
max_chars = 3000
shortened_json_str = json_str[:max_chars]

# Display the shortened JSON string
print(shortened_json_str)
# Out:
# {
#   "network": {
#     "company": [
#       "Social Bicycles Inc."
#     ],
#     "gbfs_href": "https://hamilton.socialbicycles.com/opendata/gbfs.json",
#     "href": "/v2/networks/sobi-hamilton",
#     "id": "sobi-hamilton",
#     "location": {
#       "city": "Hamilton, ON",
#       "country": "CA",
#       "latitude": 43.25643601915583,
#       "longitude": -79.86929655075073
#     },
#     "name": "SoBi",
#     "stations": [
#       {
#         "empty_slots": 8,
#         "extra": {
#           "address": "15 Hess Street North, Hamilton",
#           "last_updated": 1694021053,
#           "payment": [
#             "key",
#             "applepay",
#             "androidpay",
#             "transitcard",
#             "accountnumber",
#             "phone"
#           ],
#           "payment-terminal": false,
#           "renting": 1,
#           "returning": 1,
#           "uid": "hub_802"
#         },
#         "free_bikes": 4,
#         "id": "45dbb0009135e465f49f054517cbe74d",
#         "latitude": 43.259125842121065,
#         "longitude": -79.87721174955368,
#         "name": "Hess at king",
#         "timestamp": "2023-09-06T18:26:08.217000Z"
#       },
#       {
#         "empty_slots": 24,
#         "extra": {
#           "address": "Harbour Front Drive, North End, Hamilton, Ontario",
#           "last_updated": 1694021053,
#           "payment": [
#             "key",
#             "applepay",
#             "androidpay",
#             "transitcard",
#             "accountnumber",
#             "phone"
#           ],
#           "payment-terminal": false,
#           "renting": 1,
#           "returning": 1,
#           "uid": "hub_579"
#         },
#         "free_bikes": 8,
#         "id": "cd881edad122a75c57d94b381cdfc6c0",
#         "latitude": 43.269288276229105,
#         "longitude": -79.87132698297499,
#         "name": "Bayfront Park",
#         "timestamp": "2023-09-06T18:26:08.219000Z"
#       },
#       {
#         "empty_slots": 21,
#         "extra": {
#           "address": "325 Bay Street North, Hamilton",
#           "last_updated": 1694021053,
#           "payment": [
#             "key",
#             "applepay",
#             "androidpay",
#             "transitcard",
#             "accountnumber",
#             "phone"
#           ],
#           "payment-terminal": false,
#           "renting": 1,
#           "returning": 1,
#           "uid": "hub_578"
#         },
#         "free_bikes": 4,
#         "id": "024a3edf037cb411d16acc08a7fcb954",
#         "latitude": 43.26785864558976,
#         "longitude": -79.8679232597351,
#         "name": "Bay at Strachan",
#         "timestamp": "2023-09-06T18:26:08.220000Z"
#       },
#       {
#         "empty_slots": 7,
#         "extra": {
#           "address": "177, Bay Street North, Hess Village, Hamilton, Ontario",
#           "last_updated": 1694021053,
#           "payment": [
#             "key",
#             "applepay",
#             "androidpay",
#             "transitcard",
#             "accountnumber",
#             "phone"
#           ],
#           "payment-terminal": false,
#           "renting": 1,
#           "returning": 1,
#           "uid": "hub_577"

# %% [markdown]
# Parse through the response to get the details you want for the bike stations in that city (latitude, longitude, number of bikes).

# %%
# Extract station details
stations_data = network_json['network']['stations']
station_details = []

for station in stations_data:
    details = {
        'name': station['name'],
        'latitude': station['latitude'],
        'longitude': station['longitude'],
        'free_bikes': station['free_bikes'],
        'empty_slots': station['empty_slots'],
        'number_of_bikes': station['free_bikes']+station['empty_slots']
    }
    station_details.append(details)

# %% [markdown]
# Put your parsed results into a DataFrame.

# %%
# Create and display a DataFrame
df = pd.DataFrame(station_details)
df
# Out:
#                            name   latitude  longitude  free_bikes  \
# 0                  Hess at king  43.259126 -79.877212           4
# 1                 Bayfront Park  43.269288 -79.871327           8
# 2               Bay at Strachan  43.267859 -79.867923           4
# 3               Bay at Mulberry  43.263198 -79.871803           7
# 4                     City Hall  43.256132 -79.874499           4
# ..                          ...        ...        ...         ...
# 140          Van Wagner's Beach  43.260008 -79.766388           5
# 141       King William at James  43.257635 -79.868487           2
# 142  Westdale Village - Paisley  43.261712 -79.905901           0
# 143             Westdale Aviary  43.264869 -79.907480           2
# 144            Cannon at Ottawa  43.247565 -79.818050           3
#
#      empty_slots  number_of_bikes
# 0              8               12
# 1             24               32
# 2             21               25
# 3              7               14
# 4             13               17
# ..           ...              ...
# 140            6               11
# 141            4                6
# 142           11               11
# 143            6                8
# 144            4                7
#
# [145 rows x 6 columns]

# %%
# persist city bike networks DataFrame to a CSV file on the local disk.
df.to_csv('../data/hamilton_bike_stations.csv', index=False)

# %%
bike_stations_df = pd.read_csv('../data/hamilton_bike_stations.csv')
bike_stations_df
# Out:
#                            name   latitude  longitude  free_bikes  \
# 0                  Hess at king  43.259126 -79.877212           4
# 1                 Bayfront Park  43.269288 -79.871327           8
# 2               Bay at Strachan  43.267859 -79.867923           4
# 3               Bay at Mulberry  43.263198 -79.871803           7
# 4                     City Hall  43.256132 -79.874499           4
# ..                          ...        ...        ...         ...
# 140          Van Wagner's Beach  43.260008 -79.766388           5
# 141       King William at James  43.257635 -79.868487           2
# 142  Westdale Village - Paisley  43.261712 -79.905901           0
# 143             Westdale Aviary  43.264869 -79.907480           2
# 144            Cannon at Ottawa  43.247565 -79.818050           3
#
#      empty_slots  number_of_bikes
# 0              8               12
# 1             24               32
# 2             21               25
# 3              7               14
# 4             13               17
# ..           ...              ...
# 140            6               11
# 141            4                6
# 142           11               11
# 143            6                8
# 144            4                7
#
# [145 rows x 6 columns]
